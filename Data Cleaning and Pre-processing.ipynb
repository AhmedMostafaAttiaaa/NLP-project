# %% [markdown]
# # ***Ahmed Mostafa Attia***

# %% [markdown]
# Importing libaries (will use 'most' of them) :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
from collections import Counter
import re
# !pip install emoji
import emoji
# !pip install plotly
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# %%capture
# !pip install pyarabic
# !pip install emoji
# !pip install farasapy
# !pip install emot
# !git clone https://github.com/aub-mind/arabert.git
# !pip install arabic_reshaper

# %%
model_name="aubmindlab/bert-base-arabertv02-twitter"
model6_name='UBC-NLP/MARBERT'

arabert_prep = ArabertPreprocessor(model_name=model_name)

tokenizer = AutoTokenizer.from_pretrained(model_name)
#model = AutoModelForMaskedLM.from_pretrained("aubmindlab/bert-base-arabertv02-twitter")


deep_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/476 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/751k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# ...

# %%
# !pip install arabert

from arabert.preprocess import ArabertPreprocessor

# %%
# !pip install emot
from emot.emo_unicode import UNICODE_EMOJI ,EMOJI_UNICODE, EMOTICONS_EMO
import emoji

# List all emojis and their descriptions
for emoji_name, emoji_unicode in emoji.UNICODE_EMOJI.items():
    print(f"{emoji_name}: {emoji_unicode}")

# Convert text with emojis
text_with_emojis = "Python is fun 😃! I love programming 💻."
converted_text = emoji.demojize(text_with_emojis)
print(converted_text)

# Convert back to emojis
original_text = emoji.emojize(converted_text)
print(original_text)
# Out:
# ...
# en: {'🥇': ':1st_place_medal:', '🥈': ':2nd_place_medal:', '🥉': ':3rd_place_medal:', '🆎': ':AB_button_(blood_type):', '🏧': ':ATM_sign:', '🅰': ':A_button_(blood_type):', '🇦🇫': ':Afghanistan:', '🇦🇱': ':Albania:', '🇩🇿': ':Algeria:', '🇦🇸': ':American_Samoa:', '🇦🇩': ':Andorra:', '🇦🇴': ':Angola:', '🇦🇮': ':Anguilla:', '🇦🇶': ':Antarctica:', '🇦🇬': ':Antigua_&_Barbuda:', '♒': ':Aquarius:', '🇦🇷': ':Argentina:', '♈': ':Aries:', '🇦🇲': ':Armenia:', '🇦🇼': ':Aruba:', '🇦🇨': ':Ascension_Island:', '🇦🇺': ':Australia:', '🇦🇹': ':Austria:', '🇦🇿': ':Azerbaijan:', '🔙': ':BACK_arrow:', '🅱': ':B_button_(blood_type):', '🇧🇸': ':Bahamas:', '🇧🇭': ':Bahrain:', '🇧🇩': ':Bangladesh:', '🇧🇧': ':Barbados:', '🇧🇾': ':Belarus:', '🇧🇪': ':Belgium:', '🇧🇿': ':Belize:', '🇧🇯': ':Benin:', '🇧🇲': ':Bermuda:', '🇧🇹': ':Bhutan:', '🇧🇴': ':Bolivia:', '🇧🇦': ':Bosnia_&_Herzegovina:', '🇧🇼': ':Botswana:', '🇧🇻': ':Bouvet_Island:', '🇧🇷': ':Brazil:', '🇮🇴': ':British_Indian_Ocean_Territory:', '🇻🇬': ':British_Virgin_Islands:', '🇧🇳': ':Brunei:', '🇧🇬
# ...

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install emot
from emot.emo_unicode import UNICODE_EMOJI ,EMOJI_UNICODE, EMOTICONS_EMO
import re
import string
# !pip install arabert

from arabert.preprocess import ArabertPreprocessor
from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification,BertForSequenceClassification, AutoModelForMaskedLM,BertForPreTraining
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
# !pip install arabic-reshaper
import arabic_reshaper
from sklearn import preprocessing
import tensorflow as tf
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import validation_curve
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
import time

# %%
# %pip install --upgrade nb-js-diagrammers
# %load_ext nb_js_diagrammers

# %% [markdown]
# **To Do** -> 'flowchart'

# %%
# %%mermaid_magic -h 1750
#
# flowchart TB
#     subgraph DATASET
#         tweets[load data from data base]
#         fetch[fetch data using libraies]
#         tweets --- |or| fetch
#     end
#     split_decision{Data Already Split \nInto Test And Train?}
#     subgraph SPLIT_DATA[Split Data]
#         train_test_split[sklearn's train_test_split]
#     end
#     subgraph NORMALIZE
#         tokenize[Tokenize]
#         subgraph EXTRACT_ROOT[EXTRACT ROOT]
#             lemmetize[Lemmetize]
#             stem[Stem]
#             lemmetize --- |or| stem
#         end
#         subgraph PRE_PROCESS[PRE-PROCESS]
#             remove_stop_words[Remove Stop Words]
#             remove_emojis[Remove/decode Emojis]
#             remove_numbers[Remove/decode Numbers]
#             remove_repeated_letters[Remove/decode repated letters]
#             remove_Remove_Elongation[Remove/decode Elongation]
#             remove_ponctuation[Remove Ponctuation]
#             remove_special_characters[Remove Special Characters]
#         end
#         remove_stop_words --- |and/or| remove_emojis
#         remove_emojis --- |and/or| remove_ponctuation
#         remove_ponctuation --- |and/or| remove_special_characters
#
#         PRE_PROCESS --> tokenize
#         tokenize --> EXTRACT_ROOT
#     end
#
#     subgraph VECTORIZE
#         CountVectorizer --- |or| TfidfTransformer
#         TfidfTransformer --- |or| OneHotEncoding
#         OneHotEncoding --- |or| Word2Vec
#     end
#
#     subgraph TRAIN_CLASSIFIER[TRAIN A CLASSIFIER]
#         MultinomialNB[Sklearn's MultinomialNB naive bayes]
#         SGDClassifier[Sklearn's SGDClassifier]
#         MultinomialNB --- |or| SGDClassifier
#     end
#
#     subgraph PREDICT
#
#     end
#
#     subgraph ANALYSE
#
#     end
#
#     DATASET --> split_decision
#     split_decision --> |yes| NORMALIZE
#     split_decision --> |no| SPLIT_DATA
#     SPLIT_DATA --> NORMALIZE
#     NORMALIZE --> VECTORIZE
#     VECTORIZE --> TRAIN_CLASSIFIER;
#     TRAIN_CLASSIFIER --> PREDICT;
#     PREDICT --> ANALYSE;
#     ANALYSE --> COMPARE;
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#             flowchart TB
#     subgraph DATASET
#         tweets[load data from data base]
#         fetch[fetch data using libraies]
#         tweets --- |or| fetch
#     end
#     split_decision{Data Already Split \nInto Test And Train?}
#     subgraph SPLIT_DATA[Split Data]
#         train_test_split[sklearn&#x27;s train_test_split]
#     end
#     subgraph NORMALIZE
#         tokenize[Tokenize]
#         subgraph EXTRACT_ROOT[EXTRACT ROOT]
#             lemmetize[Lemmetize]
#             stem[Stem]
#             lemmetize --- |or| stem
#         end
#         subgraph PRE_PROCESS[PRE-PROCESS]
#             remove_stop_words[Remove Stop Words]
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Read Data and star pre-processing -> to clean data

# %%
df = pd.read_csv("/content/drive/MyDrive/ArabicTweetsCleaned.csv", lineterminator="\n") #not cleaned yet..
df.sample(5)
# Out:
#                                                      text dialect
# 141044  @Mu3azOsman 😳دقيقة نص ساعة هو شايفها ما كتيرة؟...      SD
# 37849                       @rose377_ يارب لما هو خيرا له      MA
# 84305   @DoniaMo01916286 بسله شايف نفسه عشان بقت بعشره...      EG
# 123123               @abood82_ نصاب بس مقبولة منك خيي♥️♥️      LB
# 10560         @islam_eldresi ماعندش اغنيه شينه الراجل هذا      LY

# %%
df.columns , df.info() , df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147725 entries, 0 to 147724
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     147725 non-null  object
#  1   dialect  147725 non-null  object
# dtypes: object(2)
# memory usage: 2.3+ MB
# (Index(['text', 'dialect'], dtype='object'),
#  None,
#  text       0
#  dialect    0
#  dtype: int64)

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = df['dialect'].value_counts().index ,y =df['dialect'].value_counts().values)
plt.xlabel('Dialect')
plt.title('Number of tweets per dialect')
plt.show()

# %% [markdown]
#     As seen in the figure, The data is imbalanced :

# %% [markdown]
# # DATA CLEANING AND PREPROCESSING :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Steps we gonna go through :
#
#    *  Remove URLs
#    *  Remove Punctuatuions.
#    *  Remove Elongation.
#    *  Remove Usernames(mentions)
#    *  Remove emoji
#    *  Remove Special Characters
#    *  Remove Numbers
#    *  Remove Stop words

# %%
from nltk.tokenize import word_tokenize

# %%
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
    return text
# Example
print('before Remove emoji')
print(df.iloc[387,0])
print('After Remove emoji')
convert_emojis(df.iloc[387,0][1:-1])
# Out:
# before Remove emoji
# @HHellash عاد الوزير الوحيد اللي راضي عليه الغرياني ويشكر وفي خدمته
# After Remove emoji
# 'HHellash عاد الوزير الوحيد اللي راضي عليه الغرياني ويشكر وفي خدمت'

# %%
def convert_emoticons(text):
    #text = re.escape(text)
    for emot in EMOTICONS_EMO:

        text = text.replace(emot, "_".join(EMOTICONS_EMO[emot].replace(",","").split()))
    return text
# Example
print('before Remove emoji')
print(df.iloc[1645,0])
print('After Remove emoji')
convert_emoticons(df.iloc[1645,0][1:-1])
# Out:
# before Remove emoji
# @5410b8086b7b495 علاش لا تستاهل كل خير
# After Remove emoji
# '5410b8086b7b495 علاش لا تستاهل كل خي'

# %%
punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''' + string.punctuation
Otherpunc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

stop_words = stopwords.words('arabic')
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)

# %%
def CleanData(text):

    # Remove usernames
    text = re.sub(r'@[^\s]+','',text)

    # Remove URL
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', ' ', text)

    # Remove None arabic
    text = re.sub(u"[^\u0621-\u063A\u0640-\u0652 ]", " ", text)
    text= re.sub(r'([@A-Za-z0-9_ـــــــــــــ]+)|[^\w\s]|#|http\S+', '', text)

    # Remove punctuations
    translator = str.maketrans('', '', punctuations)
    text = text.translate(translator)
    # translator2 = str.maketrans('', '', Otherpunc)
    # text = text.translate2(translator2)

    # Remove repeating character
    text = re.sub(r'(.)\1+', r'\1', text)


    # Remove tashkeel
    text = re.sub(arabic_diacritics, '', text)

    #Remove elongation
    text = re.sub("[إأآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("ة", "ه", text)
    text = re.sub("گ", "ك", text)

    text= re.sub(r'هه+', 'face_with_tears_of_joy', text)
    text= convert_emojis(text)
    text= convert_emoticons(text)

    # Remove emojis
    text=  emoji.demojize(text)
    text= re.sub(r'(:[!_\-\w]+:)', ' ', text)

    # Remove numbers
    text = ''.join(i for i in text if not i.isdigit())

    # Remove repeated letters like "الللللللللللللللله" to "الله"
    text= text[0:2] + ''.join([text[i] for i in range(2, len(text)) if text[i]!=text[i-1] or text[i]!=text[i-2]])

    # Remove stop words
    text = ' '.join(word for word in text.split() if word not in stop_words)

    return text

# %%
df['clean_text'] = df['text'].apply(lambda x: CleanData(x))
df['preprocessing'] =df['clean_text'] .apply(lambda x:arabert_prep.preprocess(x))

# %%
NewData = df.drop(columns=['text', 'clean_text'])

NewData.sample(10)
# Out:
#        dialect                                      preprocessing  \
# 10984       LY                  بالضبط امهم الي ربتهم وصرفت عليهم
# 15063       LY                                     تفاه عندي نقول
# 85862       EG                           ده اهم الحاجات الي رمضان
# 59348       EG  انها اكتشفت انها مخدوعه زي الي بتطلق فالستين ا...
# 97295       EG  بص بقي احنا عاوزين نلم الفكه الي العالم تنصيب ...
# 79687       EG    انام واوفر فلوسي القرش الابيض ينفع اليوم الاسود
# 34927       LY                             الباجي قايد السبسي مات
# 145385      SD                 حت اصفق ليك دي اتخليتك بتردحي ليهو
# 125457      LB                           حبيت اعمل خير بعتلا ياها
# 140         LY  هكي يضحكوا علي الجاهلين بالزبط دارت الكنيسه او...
#
#                                                 tokenizer
# 10984            [بالضبط, امهم, الي, ربتهم, وصرفت, عليهم]
# 15063                                  [تفاه, عندي, نقول]
# 85862                      [ده, اهم, الحاجات, الي, رمضان]
# ...

# %%
# Save the modified DataFrame to a CSV file with UTF-8 encoding
NewData = df.drop(columns=['tokenizer'])

NewData.to_csv('CleanedProcessedData.csv', index=False, encoding='utf-8')

# %%
df['clean_text'].sample()
# Out:
# 42827    اي مصلحه شعب فحال الي قال الجيب كلشي عندهم
# Name: clean_text, dtype: object

# %%
df.sample(5)
# Out:
#                                                      text dialect  \
# 47613   @HasnaaBouali1 المصيبة هو ملي تجي هذا تغريدة ص...      MA
# 104793  @diamond_mamy فيسبوء وانستجرام وسناب شاات والو...      EG
# 112419  #اين_وصلت_في_بناء_مستقبلك بلشت بالطوبار ناولني...      LB
# 7634           توا بتبدأ تبان لجان المصالحه اعتقد من غدوه      LY
# 102702  تاريخك ايه وشفت التلاجه.  امتي ودخلت بيتكو سنة...      EG
#
#                                                clean_text  \
# 47613   المصيبه ملي تجي تغريده صدفه قدام راجلك ويقراها...
# 104793  فيسبوء وانستجرام وسناب شات والواتس اب اعتكاف ف...
# 112419    اين وصلت بناء مستقبلك بلشت بالطوبار ناولني طبشه
# 7634              توا بتبدا تبان لجان المصالحه اعتقد غدوه
# 102702  تاريخك ايه وشفت التلاجه امتي ودخلت بيتكو سنه ك...
#
#                                             preprocessing
# 47613   المصيبه ملي تجي تغريده صدفه قدام راجلك ويقراها...
# 104793  فيسبوء وانستجرام وسناب شات والواتس اب اعتكاف ف...
# ...

# %% [markdown]
# Finding similarity between 'clean' and 'preprocessing'

# %%
cleanedData= df.drop(columns=['text'])
cleanedData.sample(5)
# Out:
#        dialect                                         clean_text
# 99654       EG                         متبقاش مضمون هيبهدلوك واله
# 64306       EG  لاء يكون قانون رادع ومنجز اكيد هتخف الحالات دي...
# 35147       LY  بنغازي بفكر قبلي مايعيش معنا مصراتي وطرابلسي و...
# 54092       EG                مهي النفسيه مفتاح علاج الامراض الكل
# 101963      EG                تشوف قيمه الجنيه العمله بتعتهم بكام

# %%
XX = cleanedData['dialect'].unique()
XX
# Out:
# array(['LY', 'MA', 'EG', 'LB', 'SD'], dtype=object)

# %%
df.to_csv('ProcessedData.csv', index=False, encoding='utf-8')

# %%
Fdata=

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df['tokenizer'] = df['clean_text'].apply(lambda x: word_tokenize(x))

# %%
df['tokenizer'].sample(5)
# Out:
# 125095                  [لازم, اكيد, بدك, مين, يحاكم, طوني]
# 64576     [حق, المصريه, ريس, الغريب, الي, بلدنا, الي, يق...
# 144820    [انا, عارف, دا, كلامك, انحنا, بشر, نفترض, تقول...
# 142474    [انا, مشيت, سالت, الحجه, ليه, ابوي, بعمل, كدا,...
# 107942                                  [تفضل, كانو, الطقم]
# Name: tokenizer, dtype: object

# %% [markdown]
# Check fot top words )

# %%
def top_words(dialect,n=10):
    words = [word for tokens in df[df['dialect']== dialect]['tokenizer'] for word in tokens]
    counter = Counter(words)
    indicies =[]
    counts =[]
    words = []
    for  i in counter.most_common(n):
        words.append(i[0])
        indicies.append(i[0][::-1])
        counts.append(i[1])
    return words

# %%
XX
# Out:
# array(['LY', 'MA', 'EG', 'LB', 'SD'], dtype=object)

# %%
# top_words('EG' )
top_words('MA' )
# Out:
# ['اله', 'علي', 'انا', 'الي', 'شي', 'حتي', 'راه', 'هاد', 'ديال', 'بزاف']

# %%
top_words('LY' )
# Out:
# ['الي', 'علي', 'مش', 'اله', 'انا', 'ان', 'واله', 'حتي', 'ربي', 'انت']

# %%
# cleanedData.to_csv('clean_dataset.csv')

# %%
# cleanData = pd.read_csv('/content/CleanedAndProcessedData.csv')

# %%
# cleanData.sample(10)
# Out:
#       dialect                                         clean_text
# 38436      MA  الشوال طنجه الكلب جاي برجليه عندنا اله ينعل يح...
# 36242      LY                اشارك الراي خوي محمد بصراحه شي مدهل
# 29705      LY    والي عالماده شن نظامهم والا الانجليز قعدو قهوين
# 17010      LY    يلبو الدعوات يمشو احنا نبعثو دعوات نكرسو البيوت
# 10929      LY                    بتخلينا قصدك تعالوا لمولاي محمد
# 36349      LY         وقف عالشامه انا نرسم شامات جسمها الجسم وين
# 8115       LY  مريم الحاسي معلش هلنا طرابلس السلبيه الي عندكم...
# 11948      LY  طياره تركيه دايره روحها ميته مطار مصراته خايفه...
# 19616      LY                                     تم الافراج عنه
# 9001       LY  ربي يعزك دكتور وبالتاكيد يسعدني رايك والاصل ان...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38500 entries, 0 to 38499
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dialect     38500 non-null  object
#  1   clean_text  38476 non-null  object
# dtypes: object(2)
# memory usage: 601.7+ KB

# %%
# prodata = pd.read_csv('/content/ProcessedData.csv')
# prodata.sample()
# Out:
# <ipython-input-28-d5234877bd44>:1: DtypeWarning: Columns (1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   prodata = pd.read_csv('/content/ProcessedData.csv')
#                                                     text dialect  \
# 34598  @AbubakarHesham عيدت عليك يادوك؟ \nلو ما عيدتش...      LY
#
#                                               clean_text  \
# 34598  عيدت يادوك عيدتش عام وانت بخير العايدين الفايز...
#
#                                            preprocessing
# 34598  عيدت يادوك عيدتش عام وانت بخير العايدين الفايز...

# %%
# prodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050021 entries, 0 to 1050020
# Data columns (total 4 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   text           1050021 non-null  object
#  1   dialect        147725 non-null   object
#  2   clean_text     147633 non-null   object
#  3   preprocessing  147633 non-null   object
# dtypes: object(4)
# memory usage: 32.0+ MB

# %%
# prodata.isnull().sum()
# Out:
# text                  0
# dialect          902296
# clean_text       902388
# preprocessing    902388
# dtype: int64

# %%
newdata= pd.read_csv('/content/CleanedProcessedData.csv')
newdata.sample(20)
# Out:
# <ipython-input-34-ad9d1ca4d840>:1: DtypeWarning: Columns (1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   newdata= pd.read_csv('/content/CleanedProcessedData.csv')
#                                                       text dialect  \
# 943955                 طريق العوده للبيت طويل اوي اي ده 😂😂      EG
# 474294   مايبقاش فيكم الحال غنظمو الموسم ديال مولاي عبد...     NaN
# 689455   شوفها من الناحية الإيجابية لعبنا ضد اسبانيا و ...     NaN
# 598621                           فيه الشوا  الشيخاتالفراجا     NaN
# 897821          منيب: التحالف مع العدالة والتنمية خط أحمر.     NaN
# 142813                                      المغرب 65 صوت      NaN
# 1008178               @mmhhoOda ماشين كويس ، شويه شويه ياخ      SD
# 903752          منيب: التحالف مع العدالة والتنمية خط أحمر.     NaN
# 397125   مايبقاش فيكم الحال غنظمو الموسم ديال مولاي عبد...     NaN
# 540087                           فيه الشوا  الشيخاتالفراجا     NaN
# ...

# %%
df.sample(20)
# Out:
#                                                      text dialect  \
# 116659  @2cr4Ef8r9QotONZ @hashem889 @thenewkhaleej هو ...      LB
# 27474   @jeda_sa أها أنا أحد المضحوك عليهم من هالطشة ا...      LY
# 47185   #سعد_لمجرد دخل الحبس سعد خرج تفووووو...#elmaro...      MA
# 102068      المفروض يكون الكل كده https://t.co/eTRrbuzpOT      EG
# 31332   @mansouraldaiban @sd6U20Hgzxm3QeK @moatz22hoza...      LY
# 146123  @moe_viper شوفي ليك زول يمله يومك بس وتكوني من...      SD
# 111168        ليش مين كان مفكر يزايد😂#ماحدا_يزايد_على_سعد      LB
# 136774  🌝الحافلة دي ماشه امدرمان؟😓\n🐸 آآي اركب ✌🐸👏\n🌝ب...      SD
# 23184        @abdowhite1900  علي خاطر الظلم ويبو الشفافية      LY
# 5092        @Barghathii ادلل ياغالي هذا اللي عطيته لك؟؟؟؟      LY
# 130149  @josephcaoun @DimaSadek ديما دأيما بتحط العصي ...      LB
# 132296  @LharakeMano @amalmok82 كان على مثلث خلدة او ف...      LB
# 75553   انا معرفش تعب معدتي ده هيوصل لإيه كمان هو انا ...      EG
# ...

# %%
df.isnull().sum()
# Out:
# text             0
# dialect          0
# clean_text       0
# preprocessing    0
# tokenizer        0
# dtype: int64

# %%
Data4Model = df[['preprocessing', 'dialect']]
Data4Model.sample(10)
# Out:
#                                             preprocessing dialect
# 1196    باله فكوني الي بيعيد يبلطها العام حتي بلايك نع...      LY
# 68932   وانتي مالك بقدونس انتي خليكي بلدك وربنا يعينكم...      EG
# 16791   هانا يكون الخير وصل والنت السرعه بيولي تفهمي ش...      LY
# 108539                  اله اكبر الهنا لعيونك ضحكه شفافها      LB
# 147291                          نفسه وبعدها اعترف انه كذب      SD
# 8145    رجال الاعمال صبراته فيكم شرا خروف وميصدقهمش عل...      LY
# 112759                                   العب يلا غرد يلا      LB
# 125680                           حاب يفرجينا مواهبوا عارف      LB
# 2281    روح الروح احلي رجال اله يحميلي هالوج ويسعدك يا...      LY
# 114789                            ليه بيبقي داير النق هون      LB

# %%
Data4Model.isnull().sum()
# Out:
# preprocessing    0
# dialect          0
# dtype: int64

# %%
Data4Model.to_csv('Data4Model.csv', index=False, encoding='utf-8')
